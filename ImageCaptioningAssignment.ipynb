# %% [markdown]
# <a href="https://colab.research.google.com/github/bkur808/164_assignments/blob/main/ImageCaptioningAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')
from PIL import Image
import matplotlib.pyplot as plt

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(60)

# %%
from IPython.display import Image

# %%
#Pic 1
#https://drive.google.com/file/d/1JSUSIAsastnprjqkwgeDDOLR18g5Nnsp/view?usp=drivesdk
# !gdown 1JSUSIAsastnprjqkwgeDDOLR18g5Nnsp
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JSUSIAsastnprjqkwgeDDOLR18g5Nnsp
# To: /content/9cfe426e-06bd-4dbd-ae01-d38ee9d71b08.jpg
# 100% 195k/195k [00:00<00:00, 10.2MB/s]

# %%
#Pic 2
#https://drive.google.com/file/d/1oozOca9PqGnQWKBCj-TJ_jAzuMGzzup6/view?usp=sharing
# !gdown 1oozOca9PqGnQWKBCj-TJ_jAzuMGzzup6
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oozOca9PqGnQWKBCj-TJ_jAzuMGzzup6
# To: /content/IMG_3066.jpg
# 100% 170k/170k [00:00<00:00, 79.0MB/s]

# %%
#Pic 3
#https://drive.google.com/file/d/1-0AIe3FoX7I216ps_NxCigdEBkBwEaJz/view?usp=sharing
# !gdown 1-0AIe3FoX7I216ps_NxCigdEBkBwEaJz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-0AIe3FoX7I216ps_NxCigdEBkBwEaJz
# To: /content/IMG_3337.jpg
# 100% 209k/209k [00:00<00:00, 101MB/s]

# %%
captioner = pipeline(task='image-to-text', model = 'nlpconnect/vit-gpt2-image-captioning')
captioner2 = pipeline(task='image-to-text', model='Salesforce/blip-image-captioning-base')
captioner3 = pipeline(task='image-to-text', model='microsoft/git-large-textcaps')

# %%
from PIL import Image

# If pic1 is a file path, load the image
pic1 = Image.open('/content/9cfe426e-06bd-4dbd-ae01-d38ee9d71b08.jpg')  # Enclose the path in quotes
plt.imshow(pic1)
plt.axis('off')  # Turn off the axis
plt.show()
captioner(pic1)
# Out:
# [{'generated_text': 'two men standing next to each other holding wine glasses '}]

# %%
captioner2(pic1)
# Out:
# [{'generated_text': 'a man in a tuxed shirt and a man in a tuxed shirt'}]

# %%
captioner3(pic1)
# Out:
# [{'generated_text': 'two men are standing in front of a building with a glass of champagne.'}]

# %%
pic2 = Image.open('IMG_3066.jpg')
plt.imshow(pic2)
plt.axis('off')  # Turn off the axis
plt.show()
captioner(pic2)
# Out:
# [{'generated_text': 'a man riding a horse in a field '}]

# %%
captioner2(pic2)
# Out:
# [{'generated_text': 'a man sitting on a log in the woods'}]

# %%
captioner3(pic2)
# Out:
# [{'generated_text': 'a man and woman pose in front of a tree that has a dog in it.'}]

# %%
from PIL import Image
pic3 = Image.open('IMG_3337.jpg')
plt.imshow(pic3)
plt.axis('off')  # Turn off the axis
plt.show()
captioner(pic3)
# Out:
# [{'generated_text': 'a person on a leash walking down a dirt road '}]

# %%
captioner2(pic3)
# Out:
# [{'generated_text': 'a dog is walking down a trail with a leash'}]

# %%
captioner3(pic3)
# Out:
# [{'generated_text': 'a dog with a blue collar is walking down a dirt path.'}]

# %%
captioner4 = pipeline(task='image-to-text', model='Salesforce/blip-image-captioning-large')
# Out:
# config.json:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]

# %%
print(captioner4(pic1))
print(captioner4(pic2))
print(captioner4(pic3))
# Out:
# [{'generated_text': 'they are standing next to each other holding wine glasses'}]
# [{'generated_text': 'arafed tree stump with a man and a dog in front of it'}]
# [{'generated_text': 'a close up of a dog on a leash on a dirt road'}]
